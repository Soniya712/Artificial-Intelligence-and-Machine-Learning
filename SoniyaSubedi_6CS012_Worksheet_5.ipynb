# %% [markdown]
# **Importing Dataset**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import zipfile
import random
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image, UnidentifiedImageError
import tensorflow as tf
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from sklearn.metrics import classification_report

#SMART ZIP EXTRACTION
zip_filename = "/content/drive/MyDrive/AI and Machine Learning/FruitinAmazon (1).zip"

print("🔍 Looking for the dataset zip file...")

if os.path.exists(zip_filename):
    print(f"📦 Found {zip_filename}. Extracting...")
    with zipfile.ZipFile(zip_filename, 'r') as zip_ref:
        zip_ref.extractall(".")          # Extract everything
    print("✅ Extraction completed!")
else:
    print(f"⚠️ {zip_filename} not found in the current folder.")
    print("Please upload FruitinAmazon.zip and run this cell again.")
    raise FileNotFoundError("Zip file not found.")

# AUTO-DETECT train/ and test/ folders
def find_dataset_folders():
    for root, dirs, files in os.walk('.'):
        if 'train' in dirs and 'test' in dirs:
            train_path = os.path.join(root, 'train')
            test_path = os.path.join(root, 'test')
            print(f"✅ Found dataset at: {root}")
            return train_path, test_path
    # Fallback: look for any folder named 'train'
    for root, dirs, files in os.walk('.'):
        if 'train' in dirs:
            return os.path.join(root, 'train'), None
    return None, None

train_dir, test_dir = find_dataset_folders()

if train_dir and os.path.exists(train_dir):
    print(f"Train folder set to: {train_dir}")
else:
    print("Could not find 'train' folder even after extraction.")
    print("Please check the zip structure and tell me what folders you see after extraction.")

if test_dir and os.path.exists(test_dir):
    print(f"Test folder set to : {test_dir}")
else:
    print("'test' folder not found (some datasets have only train). Using validation split instead.")

# %matplotlib inline
plt.style.use('seaborn-v0_8')
print("Setup complete! You can now run the next cells.")
# Out:
# 🔍 Looking for the dataset zip file...
# 📦 Found /content/drive/MyDrive/AI and Machine Learning/FruitinAmazon (1).zip. Extracting...
# ✅ Extraction completed!
# ✅ Found dataset at: ./FruitinAmazon
# Train folder set to: ./FruitinAmazon/train
# Test folder set to : ./FruitinAmazon/test
# Setup complete! You can now run the next cells.

# %% [markdown]
# **Task 1: Data Understanding and Visualization:**

# %%
classes = [d for d in os.listdir(train_dir) if os.path.isdir(os.path.join(train_dir, d))]
print(f"Found {len(classes)} classes: {classes}")

images_to_show = []
labels_to_show = []

for cls in classes:
    class_dir = os.path.join(train_dir, cls)
    img_files = [f for f in os.listdir(class_dir) if f.lower().endswith(('.png', '.jpg', '.jpeg'))]
    if img_files:
        img_file = random.choice(img_files)
        img_path = os.path.join(class_dir, img_file)
        images_to_show.append(img_path)
        labels_to_show.append(cls)

fig, axes = plt.subplots(2, 3, figsize=(15, 10))
fig.suptitle('Random Sample Images from Each Fruit Class (Train)', fontsize=18)

for i, ax in enumerate(axes.flat):
    if i < len(images_to_show):
        img = Image.open(images_to_show[i])
        ax.imshow(img)
        ax.set_title(labels_to_show[i], fontsize=14)
        ax.axis('off')

plt.tight_layout()
plt.show()
# Out:
# Found 6 classes: ['graviola', 'pupunha', 'acai', 'cupuacu', 'guarana', 'tucuma']

# %% [markdown]
# **Check for Corrupted Image**

# %%
def check_corrupted(train_dir):
    corrupted = []
    for cls in os.listdir(train_dir):
        class_dir = os.path.join(train_dir, cls)
        if os.path.isdir(class_dir):
            for filename in os.listdir(class_dir):
                img_path = os.path.join(class_dir, filename)
                try:
                    with Image.open(img_path) as img:
                        img.verify()
                except (UnidentifiedImageError, IOError, SyntaxError):
                    corrupted.append(img_path)
                    os.remove(img_path)
                    print(f"🗑 Removed: {img_path}")
    print("✅ No corrupted images found." if not corrupted else f"Removed {len(corrupted)} corrupted images.")
check_corrupted(train_dir)
# Out:
# ✅ No corrupted images found.

# %% [markdown]
# **Task 2: Loading and Preprocessing Image Data in keras:**

# %%
img_height = 128
img_width = 128
batch_size = 16
validation_split = 0.2

rescale = tf.keras.layers.Rescaling(1./255)

# 1. Create datasets FIRST (before mapping)
raw_train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    train_dir,
    labels='inferred',
    label_mode='int',
    image_size=(img_height, img_width),
    batch_size=batch_size,
    shuffle=True,
    validation_split=validation_split,
    subset='training',
    seed=123
)

raw_val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    train_dir,
    labels='inferred',
    label_mode='int',
    image_size=(img_height, img_width),
    batch_size=batch_size,
    shuffle=False,
    validation_split=validation_split,
    subset='validation',
    seed=123
)

raw_test_ds = tf.keras.preprocessing.image_dataset_from_directory(
    test_dir,
    labels='inferred',
    label_mode='int',
    image_size=(img_height, img_width),
    batch_size=batch_size,
    shuffle=False
)

# 2. Get class_names BEFORE applying map (this is the fix)
class_names = raw_train_ds.class_names
num_classes = len(class_names)

# 3. Now apply normalization
train_ds = raw_train_ds.map(lambda x, y: (rescale(x), y))
val_ds   = raw_val_ds.map(lambda x, y: (rescale(x), y))
test_ds  = raw_test_ds.map(lambda x, y: (rescale(x), y))

print(f"✅ Classes: {class_names}")
print(f"Training samples : {len(train_ds) * batch_size}")
print(f"Validation samples: {len(val_ds) * batch_size}")
print(f"Test samples     : {len(test_ds) * batch_size}")
print("✅ Datasets loaded and normalized successfully!")
# Out:
# Found 90 files belonging to 6 classes.
# Using 72 files for training.
# Found 90 files belonging to 6 classes.
# Using 18 files for validation.
# Found 30 files belonging to 6 classes.
# ✅ Classes: ['acai', 'cupuacu', 'graviola', 'guarana', 'pupunha', 'tucuma']
# Training samples : 80
# Validation samples: 32
# Test samples     : 32
# ✅ Datasets loaded and normalized successfully!

# %% [markdown]
# **Task 3 - Implement a CNN with**
# **Follow the following Structure and Hyper - parameters:**

# %%
#TASK 3: CNN Model
model = tf.keras.Sequential([
    tf.keras.layers.Conv2D(32, (3, 3), padding='same', activation='relu',
                           input_shape=(img_height, img_width, 3)),
    tf.keras.layers.MaxPooling2D((2, 2), strides=2),

    tf.keras.layers.Conv2D(32, (3, 3), padding='same', activation='relu'),
    tf.keras.layers.MaxPooling2D((2, 2), strides=2),

    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(num_classes, activation='softmax')
])

model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 128, 128, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 64, 64, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 64, 64, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 32, 32, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 32768)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │     2,097,216 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │         8,320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 6)              │           774 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,116,454 (8.07 MB)
#  Trainable params: 2,116,454 (8.07 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# **Task 4: Compile the Model**

# %%
#TASK 4: Compile
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

checkpoint = ModelCheckpoint('best_fruit_model.h5', monitor='val_loss',
                             save_best_only=True, mode='min', verbose=1)
early_stop = EarlyStopping(monitor='val_loss', patience=10,
                           restore_best_weights=True, verbose=1)

history = model.fit(train_ds, epochs=250, validation_data=val_ds,
                    callbacks=[checkpoint, early_stop])
# Out:
# Epoch 1/250
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step - accuracy: 0.1333 - loss: 1.8389
# Epoch 1: val_loss improved from None to 1.64711, saving model to best_fruit_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 1: finished saving model to best_fruit_model.h5
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 4s 358ms/step - accuracy: 0.1250 - loss: 1.8475 - val_accuracy: 0.3889 - val_loss: 1.6471
# Epoch 2/250
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step - accuracy: 0.4135 - loss: 1.6274
# Epoch 2: val_loss improved from 1.64711 to 1.35400, saving model to best_fruit_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 2: finished saving model to best_fruit_model.h5
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 300ms/step - accuracy: 0.4167 - loss: 1.6064 - val_accuracy: 0.6111 - val_loss: 1.3540
# Epoch 3/250
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 343ms/step - accuracy: 0.7156 - loss: 1.3078
# Epoch 3: val_loss improved from 1.35400 to 1.26402, saving model to best_fruit_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 3: finished saving model to best_fruit_model.h5
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 433ms/step - accuracy: 0.7500 - loss: 1.1971 - val_accuracy: 0.5000 - val_loss: 1.2640
# Epoch 4/250
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step - accuracy: 0.7628 - loss: 0.7948
# Epoch 4: val_loss improved from 1.26402 to 0.67372, saving model to best_fruit_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 4: finished saving model to best_fruit_model.h5
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 510ms/step - accuracy: 0.7778 - loss: 0.7780 - val_accuracy: 0.7778 - val_loss: 0.6737
# Epoch 5/250
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 357ms/step - accuracy: 0.7868 - loss: 0.5692
# Epoch 5: val_loss did not improve from 0.67372
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 402ms/step - accuracy: 0.8194 - loss: 0.5582 - val_accuracy: 0.3333 - val_loss: 1.4635
# Epoch 6/250
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - accuracy: 0.7524 - loss: 0.4545
# Epoch 6: val_loss did not improve from 0.67372
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 311ms/step - accuracy: 0.8194 - loss: 0.3899 - val_accuracy: 0.7222 - val_loss: 0.7246
# Epoch 7/250
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step - accuracy: 0.8962 - loss: 0.2953
# Epoch 7: val_loss improved from 0.67372 to 0.52756, saving model to best_fruit_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 7: finished saving model to best_fruit_model.h5
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 304ms/step - accuracy: 0.9028 - loss: 0.2900 - val_accuracy: 0.8333 - val_loss: 0.5276
# Epoch 8/250
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step - accuracy: 0.9882 - loss: 0.1290
# Epoch 8: val_loss improved from 0.52756 to 0.47512, saving model to best_fruit_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 8: finished saving model to best_fruit_model.h5
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 315ms/step - accuracy: 0.9722 - loss: 0.1502 - val_accuracy: 0.7778 - val_loss: 0.4751
# Epoch 9/250
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step - accuracy: 1.0000 - loss: 0.0694
# Epoch 9: val_loss improved from 0.47512 to 0.36223, saving model to best_fruit_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 9: finished saving model to best_fruit_model.h5
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 314ms/step - accuracy: 1.0000 - loss: 0.0694 - val_accuracy: 0.8333 - val_loss: 0.3622
# Epoch 10/250
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 255ms/step - accuracy: 1.0000 - loss: 0.0190
# Epoch 10: val_loss did not improve from 0.36223
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 294ms/step - accuracy: 1.0000 - loss: 0.0222 - val_accuracy: 0.8333 - val_loss: 0.4956
# Epoch 11/250
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step - accuracy: 1.0000 - loss: 0.0127
# Epoch 11: val_loss did not improve from 0.36223
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 289ms/step - accuracy: 1.0000 - loss: 0.0130 - val_accuracy: 0.8333 - val_loss: 0.4685
# Epoch 12/250
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 590ms/step - accuracy: 1.0000 - loss: 0.0044
# Epoch 12: val_loss did not improve from 0.36223
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 737ms/step - accuracy: 1.0000 - loss: 0.0041 - val_accuracy: 0.8333 - val_loss: 0.3831
# Epoch 13/250
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step - accuracy: 1.0000 - loss: 0.0029
# Epoch 13: val_loss improved from 0.36223 to 0.34030, saving model to best_fruit_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 13: finished saving model to best_fruit_model.h5
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 313ms/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 0.8333 - val_loss: 0.3403
# Epoch 14/250
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 261ms/step - accuracy: 1.0000 - loss: 0.0026
# Epoch 14: val_loss improved from 0.34030 to 0.30307, saving model to best_fruit_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 14: finished saving model to best_fruit_model.h5
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 326ms/step - accuracy: 1.0000 - loss: 0.0023 - val_accuracy: 0.8333 - val_loss: 0.3031
# Epoch 15/250
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step - accuracy: 1.0000 - loss: 0.0017
# Epoch 15: val_loss improved from 0.30307 to 0.28560, saving model to best_fruit_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 15: finished saving model to best_fruit_model.h5
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 312ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.8333 - val_loss: 0.2856
# Epoch 16/250
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step - accuracy: 1.0000 - loss: 0.0014
# Epoch 16: val_loss did not improve from 0.28560
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 291ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.8333 - val_loss: 0.3008
# Epoch 17/250
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step - accuracy: 1.0000 - loss: 8.3851e-04
# Epoch 17: val_loss did not improve from 0.28560
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 292ms/step - accuracy: 1.0000 - loss: 8.2008e-04 - val_accuracy: 0.8333 - val_loss: 0.3225
# Epoch 18/250
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 255ms/step - accuracy: 1.0000 - loss: 6.9466e-04
# Epoch 18: val_loss did not improve from 0.28560
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 294ms/step - accuracy: 1.0000 - loss: 6.9499e-04 - val_accuracy: 0.8333 - val_loss: 0.3493
# Epoch 19/250
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step - accuracy: 1.0000 - loss: 6.2291e-04
# Epoch 19: val_loss did not improve from 0.28560
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 513ms/step - accuracy: 1.0000 - loss: 6.1441e-04 - val_accuracy: 0.8333 - val_loss: 0.3730
# Epoch 20/250
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 421ms/step - accuracy: 1.0000 - loss: 5.4574e-04
# Epoch 20: val_loss did not improve from 0.28560
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 3s 510ms/step - accuracy: 1.0000 - loss: 5.5905e-04 - val_accuracy: 0.8333 - val_loss: 0.3892
# Epoch 21/250
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 255ms/step - accuracy: 1.0000 - loss: 5.1073e-04
# Epoch 21: val_loss did not improve from 0.28560
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 293ms/step - accuracy: 1.0000 - loss: 5.1287e-04 - val_accuracy: 0.8333 - val_loss: 0.3940
# Epoch 22/250
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 258ms/step - accuracy: 1.0000 - loss: 4.7019e-04
# Epoch 22: val_loss did not improve from 0.28560
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 303ms/step - accuracy: 1.0000 - loss: 4.7482e-04 - val_accuracy: 0.8333 - val_loss: 0.3973
# Epoch 23/250
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step - accuracy: 1.0000 - loss: 4.7265e-04
# Epoch 23: val_loss did not improve from 0.28560
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 289ms/step - accuracy: 1.0000 - loss: 4.4671e-04 - val_accuracy: 0.8333 - val_loss: 0.3960
# Epoch 24/250
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step - accuracy: 1.0000 - loss: 4.4381e-04
# Epoch 24: val_loss did not improve from 0.28560
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 289ms/step - accuracy: 1.0000 - loss: 4.2324e-04 - val_accuracy: 0.8333 - val_loss: 0.3958
# Epoch 25/250
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 255ms/step - accuracy: 1.0000 - loss: 3.9440e-04
# Epoch 25: val_loss did not improve from 0.28560
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 301ms/step - accuracy: 1.0000 - loss: 4.0164e-04 - val_accuracy: 0.8333 - val_loss: 0.3959
# Epoch 25: early stopping
# Restoring model weights from the end of the best epoch: 15.

# %%
plt.figure(figsize=(14, 5))
plt.subplot(1,2,1)
plt.plot(history.history['accuracy'], label='Train')
plt.plot(history.history['val_accuracy'], label='Validation')
plt.title('Accuracy'); plt.legend()

plt.subplot(1,2,2)
plt.plot(history.history['loss'], label='Train')
plt.plot(history.history['val_loss'], label='Validation')
plt.title('Loss'); plt.legend()
plt.show()

# %% [markdown]
# **Task 5: Evaluate the Model**

# %%
#TASK 5: Evaluate on Test Set
test_loss, test_acc = model.evaluate(test_ds)
print(f"✅ Test Accuracy: {test_acc:.4f} | Test Loss: {test_loss:.4f}")
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.7667 - loss: 0.5926
# ✅ Test Accuracy: 0.7667 | Test Loss: 0.5926

# %% [markdown]
# **Task 6: Save and Load the Model**

# %%
model.save('fruit_classifier_final.h5')
print("✅ Model saved as fruit_classifier_final.h5")
loaded_model = tf.keras.models.load_model('fruit_classifier_final.h5')
loaded_loss, loaded_acc = loaded_model.evaluate(test_ds)
print(f"✅ Loaded model Test Accuracy: {loaded_acc:.4f}")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# ✅ Model saved as fruit_classifier_final.h5
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 88ms/step - accuracy: 0.7667 - loss: 0.5926
# ✅ Loaded model Test Accuracy: 0.7667

# %% [markdown]
# **Task 7: Predictions and Classification Report**

# %%
# TASK 7: Classification Report on Test
predictions = model.predict(test_ds)
predicted_labels = np.argmax(predictions, axis=1)

true_labels = []
for _, labels in test_ds:
    true_labels.extend(labels.numpy())
true_labels = np.array(true_labels)

print("="*70)
print("CLASSIFICATION REPORT (TEST SET)")
print("="*70)
print(classification_report(true_labels, predicted_labels,
                           target_names=class_names, digits=2))
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step
# ======================================================================
# CLASSIFICATION REPORT (TEST SET)
# ======================================================================
#               precision    recall  f1-score   support
#
#         acai       0.62      1.00      0.77         5
#      cupuacu       1.00      1.00      1.00         5
#     graviola       0.80      0.80      0.80         5
#      guarana       0.67      0.80      0.73         5
#      pupunha       0.75      0.60      0.67         5
#       tucuma       1.00      0.40      0.57         5
#
#     accuracy                           0.77        30
#    macro avg       0.81      0.77      0.76        30
# weighted avg       0.81      0.77      0.76        30
